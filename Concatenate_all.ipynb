# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/colab_libs')
# Out:
# Mounted at /content/drive

# %%
! pip install mne
! pip install scipy
! pip install mne
import numpy as np
import scipy.io
import mne
# Out:
# Collecting mne
#   Downloading mne-1.10.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.12/dist-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.7 in /usr/local/lib/python3.12/dist-packages (from mne) (3.10.0)
# Requirement already satisfied: numpy<3,>=1.25 in /usr/local/lib/python3.12/dist-packages (from mne) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mne) (25.0)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.12/dist-packages (from mne) (1.8.2)
# Requirement already satisfied: scipy>=1.11 in /usr/local/lib/python3.12/dist-packages (from mne) (1.16.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from mne) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->mne) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->mne) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->mne) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->mne) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->mne) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->mne) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.5->mne) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.5->mne) (2.32.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->mne) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7->mne) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2025.8.3)
# Downloading mne-1.10.1-py3-none-any.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 12.1 MB/s eta 0:00:00
# Installing collected packages: mne
# Successfully installed mne-1.10.1
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.1)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from scipy) (2.0.2)
# Requirement already satisfied: mne in /usr/local/lib/python3.12/dist-packages (1.10.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.12/dist-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.7 in /usr/local/lib/python3.12/dist-packages (from mne) (3.10.0)
# Requirement already satisfied: numpy<3,>=1.25 in /usr/local/lib/python3.12/dist-packages (from mne) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mne) (25.0)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.12/dist-packages (from mne) (1.8.2)
# Requirement already satisfied: scipy>=1.11 in /usr/local/lib/python3.12/dist-packages (from mne) (1.16.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from mne) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->mne) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->mne) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->mne) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->mne) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->mne) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->mne) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.5->mne) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.5->mne) (2.32.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->mne) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7->mne) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2025.8.3)

# %%
from pathlib import Path
import numpy as np
import scipy.io as sio
import mne

def mat_to_raw(fname):
    mat   = sio.loadmat(fname, squeeze_me=True, struct_as_record=False)
    EEG   = mat['EEG']
    data  = np.asarray(EEG.data) * 1e-6   # μV -> V
    sfreq = float(EEG.srate)
    ch_names = [c.labels for c in np.atleast_1d(EEG.chanlocs)]
    info = mne.create_info(ch_names, sfreq, ch_types='eeg')
    return mne.io.RawArray(data, info, verbose=False)

def events_from_mat(fname):
    m   = sio.loadmat(fname, squeeze_me=True, struct_as_record=False)
    EEG = m['EEG']
    evs = []
    for ev in np.atleast_1d(EEG.event):
        sample = int(round(ev.latency)) - 1   # EEGLAB 多为 1-based
        code   = int(ev.type)
        evs.append([sample, 0, code])
    return np.asarray(evs, dtype=int)

def add_stim(raw, events, name='STI'):
    stim = np.zeros(raw.n_times, float)
    stim[events[:, 0]] = events[:, 2]
    info = mne.create_info([name], raw.info['sfreq'], ['stim'])
    raw.add_channels([mne.io.RawArray(stim[None, :], info)], force_update_info=True)


def concat_nr_tsr(nr_folder, tsr_folder):

    files = []
    files += sorted(Path(nr_folder).glob("*NR*_EEG.mat"))
    files += sorted(Path(tsr_folder).glob("*TSR*_EEG.mat"))


    raws = []
    dropped = []

    for f in files:
      r = mat_to_raw(f)
      ev = events_from_mat(f)
      add_stim(r, ev, name='STI')
      r_copy = r.copy()

      r_copy.filter(l_freq=2., h_freq=None, picks="eeg", verbose=False)

      data_eeg = r_copy.get_data(picks="eeg")
      std = data_eeg.std(axis=1, keepdims=True)

      mask = (np.abs(data_eeg) <= 3 * std).all(axis=0)
      data_eeg_clean = data_eeg[:, mask]

      sd = data_eeg_clean.std()
      if sd < 1e-4:   # 100 µV = 1e-4 V
          raws.append(r)
      else:
          dropped.append(f.name)

    print("fiels deleted:", dropped if dropped else "no fiels dropped")



    raw_all = mne.concatenate_raws(raws)
    print(f"concatenated: {len(raws)} files, total times ≈ {raw_all.n_times/raw_all.info['sfreq']:.1f}s")

    events = mne.find_events(raw_all, stim_channel='STI', shortest_event=1)
    return raw_all, events, dropped


# pplied the ±3SD time-point mask to the STI channel as wel
# That truncated some stimulus pulses to just 1 sample.
# mne.find_events expects each event to be at least 2 samples long by default

# %%
from pathlib import Path

nr_root  = "/content/drive/MyDrive/Zuco2/task1 - NR/Raw data"
tsr_root = "/content/drive/MyDrive/Zuco2/task2 - TSR/Raw data"

subjects = sorted([d.name for d in Path(nr_root).iterdir() if d.is_dir()])

subj_raws = {}
all_dropped_files = []

for sub in subjects:
  print(f"\nprocessing {sub} ...")
  raw_all, events, dropped = concat_nr_tsr(Path(nr_root)/sub, Path(tsr_root)/sub)


  subj_raws[sub] = raw_all

  all_dropped_files.extend(dropped)

print(f"\nDropped in total {len(all_dropped_files)} files：")
for fname in all_dropped_files:
  print("  -", fname)
# Out:
# processing YAC ...
# Creating RawArray with float64 data, n_channels=1, n_times=225411
#     Range : 0 ... 225410 =      0.000 ...   450.820 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=157559
#     Range : 0 ... 157558 =      0.000 ...   315.116 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=133507
#     Range : 0 ... 133506 =      0.000 ...   267.012 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=106505
#     Range : 0 ... 106504 =      0.000 ...   213.008 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=108049
#     Range : 0 ... 108048 =      0.000 ...   216.096 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=97277
#     Range : 0 ... 97276 =      0.000 ...   194.552 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=118755
#     Range : 0 ... 118754 =      0.000 ...   237.508 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=170233
#     Range : 0 ... 170232 =      0.000 ...   340.464 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=227335
#     Range : 0 ... 227334 =      0.000 ...   454.668 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=122831
#     Range : 0 ... 122830 =      0.000 ...   245.660 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=153677
#     Range : 0 ... 153676 =      0.000 ...   307.352 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=93326
#     Range : 0 ... 93325 =      0.000 ...   186.650 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=100279
#     Range : 0 ... 100278 =      0.000 ...   200.556 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=71053
#     Range : 0 ... 71052 =      0.000 ...   142.104 secs
# Ready.
# fiels deleted: ['YAC_NR5_EEG.mat', 'YAC_NR6_EEG.mat', 'YAC_TSR4_EEG.mat', 'YAC_TSR5_EEG.mat']
# concatenated: 10 files, total times ≈ 2866.9s
# Finding events on: STI
# 1096 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  96 110 111 112 115 116]
#
# processing YAG ...
# Creating RawArray with float64 data, n_channels=1, n_times=347416
#     Range : 0 ... 347415 =      0.000 ...   694.830 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=224310
#     Range : 0 ... 224309 =      0.000 ...   448.618 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=194485
#     Range : 0 ... 194484 =      0.000 ...   388.968 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=175584
#     Range : 0 ... 175583 =      0.000 ...   351.166 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=167882
#     Range : 0 ... 167881 =      0.000 ...   335.762 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=168209
#     Range : 0 ... 168208 =      0.000 ...   336.416 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=193409
#     Range : 0 ... 193408 =      0.000 ...   386.816 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=320540
#     Range : 0 ... 320539 =      0.000 ...   641.078 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=373317
#     Range : 0 ... 373316 =      0.000 ...   746.632 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=244436
#     Range : 0 ... 244435 =      0.000 ...   488.870 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=290789
#     Range : 0 ... 290788 =      0.000 ...   581.576 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=182809
#     Range : 0 ... 182808 =      0.000 ...   365.616 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=203985
#     Range : 0 ... 203984 =      0.000 ...   407.968 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=125807
#     Range : 0 ... 125806 =      0.000 ...   251.612 secs
# Ready.
# fiels deleted: no fiels dropped
# concatenated: 14 files, total times ≈ 6426.0s
# Finding events on: STI
# 1552 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  94  95  96 110 111 112 113
#  114 115 116]
#
# processing YAK ...
# Creating RawArray with float64 data, n_channels=1, n_times=7599
#     Range : 0 ... 7598 =      0.000 ...    15.196 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=131832
#     Range : 0 ... 131831 =      0.000 ...   263.662 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=121605
#     Range : 0 ... 121604 =      0.000 ...   243.208 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=123606
#     Range : 0 ... 123605 =      0.000 ...   247.210 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=127380
#     Range : 0 ... 127379 =      0.000 ...   254.758 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=115580
#     Range : 0 ... 115579 =      0.000 ...   231.158 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=139931
#     Range : 0 ... 139930 =      0.000 ...   279.860 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=132605
#     Range : 0 ... 132604 =      0.000 ...   265.208 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=198433
#     Range : 0 ... 198432 =      0.000 ...   396.864 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=166232
#     Range : 0 ... 166231 =      0.000 ...   332.462 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=219435
#     Range : 0 ... 219434 =      0.000 ...   438.868 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=154833
#     Range : 0 ... 154832 =      0.000 ...   309.664 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=191284
#     Range : 0 ... 191283 =      0.000 ...   382.566 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=114654
#     Range : 0 ... 114653 =      0.000 ...   229.306 secs
# Ready.
# fiels deleted: no fiels dropped
# concatenated: 14 files, total times ≈ 3890.0s
# Finding events on: STI
# 1552 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  94  95  96 110 111 112 113
#  114 115 116]
#
# processing YDG ...
# Creating RawArray with float64 data, n_channels=1, n_times=198585
#     Range : 0 ... 198584 =      0.000 ...   397.168 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=126406
#     Range : 0 ... 126405 =      0.000 ...   252.810 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=136856
#     Range : 0 ... 136855 =      0.000 ...   273.710 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=131031
#     Range : 0 ... 131030 =      0.000 ...   262.060 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=133206
#     Range : 0 ... 133205 =      0.000 ...   266.410 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=109281
#     Range : 0 ... 109280 =      0.000 ...   218.560 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=120605
#     Range : 0 ... 120604 =      0.000 ...   241.208 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=95504
#     Range : 0 ... 95503 =      0.000 ...   191.006 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=147456
#     Range : 0 ... 147455 =      0.000 ...   294.910 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=116080
#     Range : 0 ... 116079 =      0.000 ...   232.158 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=125032
#     Range : 0 ... 125031 =      0.000 ...   250.062 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=107055
#     Range : 0 ... 107054 =      0.000 ...   214.108 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=125782
#     Range : 0 ... 125781 =      0.000 ...   251.562 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=76628
#     Range : 0 ... 76627 =      0.000 ...   153.254 secs
# Ready.
# fiels deleted: ['YDG_NR5_EEG.mat', 'YDG_TSR5_EEG.mat', 'YDG_TSR6_EEG.mat']
# concatenated: 11 files, total times ≈ 2766.9s
# Finding events on: STI
# 1212 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  95  96 110 111 112 113 116]
#
# processing YDR ...
# Creating RawArray with float64 data, n_channels=1, n_times=214110
#     Range : 0 ... 214109 =      0.000 ...   428.218 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=129032
#     Range : 0 ... 129031 =      0.000 ...   258.062 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=115480
#     Range : 0 ... 115479 =      0.000 ...   230.958 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=110530
#     Range : 0 ... 110529 =      0.000 ...   221.058 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=89929
#     Range : 0 ... 89928 =      0.000 ...   179.856 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=88804
#     Range : 0 ... 88803 =      0.000 ...   177.606 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=86406
#     Range : 0 ... 86405 =      0.000 ...   172.810 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=70203
#     Range : 0 ... 70202 =      0.000 ...   140.404 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=87829
#     Range : 0 ... 87828 =      0.000 ...   175.656 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=66328
#     Range : 0 ... 66327 =      0.000 ...   132.654 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=81903
#     Range : 0 ... 81902 =      0.000 ...   163.804 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=80377
#     Range : 0 ... 80376 =      0.000 ...   160.752 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=44351
#     Range : 0 ... 44350 =      0.000 ...    88.700 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=47603
#     Range : 0 ... 47602 =      0.000 ...    95.204 secs
# Ready.
# fiels deleted: no fiels dropped
# concatenated: 14 files, total times ≈ 2625.8s
# Finding events on: STI
# 1552 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  94  95  96 110 111 112 113
#  114 115 116]
#
# processing YFR ...
# Creating RawArray with float64 data, n_channels=1, n_times=251513
#     Range : 0 ... 251512 =      0.000 ...   503.024 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=199159
#     Range : 0 ... 199158 =      0.000 ...   398.316 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=200560
#     Range : 0 ... 200559 =      0.000 ...   401.118 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=183308
#     Range : 0 ... 183307 =      0.000 ...   366.614 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=163508
#     Range : 0 ... 163507 =      0.000 ...   327.014 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=142832
#     Range : 0 ... 142831 =      0.000 ...   285.662 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=157432
#     Range : 0 ... 157431 =      0.000 ...   314.862 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=161110
#     Range : 0 ... 161109 =      0.000 ...   322.218 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=297761
#     Range : 0 ... 297760 =      0.000 ...   595.520 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=175658
#     Range : 0 ... 175657 =      0.000 ...   351.314 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=159033
#     Range : 0 ... 159032 =      0.000 ...   318.064 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=167608
#     Range : 0 ... 167607 =      0.000 ...   335.214 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=94706
#     Range : 0 ... 94705 =      0.000 ...   189.410 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=83979
#     Range : 0 ... 83978 =      0.000 ...   167.956 secs
# Ready.
# fiels deleted: ['YFR_TSR2_EEG.mat']
# concatenated: 13 files, total times ≈ 4280.8s
# Finding events on: STI
# 1406 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  94  95  96 110 112 113 114
#  115 116]
#
# processing YFS ...
# Creating RawArray with float64 data, n_channels=1, n_times=194135
#     Range : 0 ... 194134 =      0.000 ...   388.268 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=121032
#     Range : 0 ... 121031 =      0.000 ...   242.062 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=109430
#     Range : 0 ... 109429 =      0.000 ...   218.858 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=95405
#     Range : 0 ... 95404 =      0.000 ...   190.808 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=102055
#     Range : 0 ... 102054 =      0.000 ...   204.108 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=80929
#     Range : 0 ... 80928 =      0.000 ...   161.856 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=104730
#     Range : 0 ... 104729 =      0.000 ...   209.458 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=71678
#     Range : 0 ... 71677 =      0.000 ...   143.354 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=116455
#     Range : 0 ... 116454 =      0.000 ...   232.908 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=84179
#     Range : 0 ... 84178 =      0.000 ...   168.356 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=101080
#     Range : 0 ... 101079 =      0.000 ...   202.158 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=83579
#     Range : 0 ... 83578 =      0.000 ...   167.156 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=74579
#     Range : 0 ... 74578 =      0.000 ...   149.156 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=54127
#     Range : 0 ... 54126 =      0.000 ...   108.252 secs
# Ready.
# fiels deleted: no fiels dropped
# concatenated: 14 files, total times ≈ 2786.8s
# Finding events on: STI
# 1552 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  94  95  96 110 111 112 113
#  114 115 116]
#
# processing YHS ...
# Creating RawArray with float64 data, n_channels=1, n_times=142382
#     Range : 0 ... 142381 =      0.000 ...   284.762 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=93829
#     Range : 0 ... 93828 =      0.000 ...   187.656 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=93004
#     Range : 0 ... 93003 =      0.000 ...   186.006 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=91129
#     Range : 0 ... 91128 =      0.000 ...   182.256 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=84305
#     Range : 0 ... 84304 =      0.000 ...   168.608 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=76178
#     Range : 0 ... 76177 =      0.000 ...   152.354 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=82904
#     Range : 0 ... 82903 =      0.000 ...   165.806 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=43152
#     Range : 0 ... 43151 =      0.000 ...    86.302 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=87730
#     Range : 0 ... 87729 =      0.000 ...   175.458 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=87131
#     Range : 0 ... 87130 =      0.000 ...   174.260 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=90704
#     Range : 0 ... 90703 =      0.000 ...   181.406 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=72078
#     Range : 0 ... 72077 =      0.000 ...   144.154 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=60503
#     Range : 0 ... 60502 =      0.000 ...   121.004 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=53477
#     Range : 0 ... 53476 =      0.000 ...   106.952 secs
# Ready.
# fiels deleted: no fiels dropped
# concatenated: 14 files, total times ≈ 2317.0s
# Finding events on: STI
# 1552 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  94  95  96 110 111 112 113
#  114 115 116]
#
# processing YIS ...
# Creating RawArray with float64 data, n_channels=1, n_times=229335
#     Range : 0 ... 229334 =      0.000 ...   458.668 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=159583
#     Range : 0 ... 159582 =      0.000 ...   319.164 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=151832
#     Range : 0 ... 151831 =      0.000 ...   303.662 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=144533
#     Range : 0 ... 144532 =      0.000 ...   289.064 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=150056
#     Range : 0 ... 150055 =      0.000 ...   300.110 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=142108
#     Range : 0 ... 142107 =      0.000 ...   284.214 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=157234
#     Range : 0 ... 157233 =      0.000 ...   314.466 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=90204
#     Range : 0 ... 90203 =      0.000 ...   180.406 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=74879
#     Range : 0 ... 74878 =      0.000 ...   149.756 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=73853
#     Range : 0 ... 73852 =      0.000 ...   147.704 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=80077
#     Range : 0 ... 80076 =      0.000 ...   160.152 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=94379
#     Range : 0 ... 94378 =      0.000 ...   188.756 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=56054
#     Range : 0 ... 56053 =      0.000 ...   112.106 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=61853
#     Range : 0 ... 61852 =      0.000 ...   123.704 secs
# Ready.
# fiels deleted: no fiels dropped
# concatenated: 14 files, total times ≈ 3332.0s
# Finding events on: STI
# 1552 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  94  95  96 110 111 112 113
#  114 115 116]
#
# processing YLS ...
# Creating RawArray with float64 data, n_channels=1, n_times=275639
#     Range : 0 ... 275638 =      0.000 ...   551.276 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=151806
#     Range : 0 ... 151805 =      0.000 ...   303.610 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=144257
#     Range : 0 ... 144256 =      0.000 ...   288.512 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=139007
#     Range : 0 ... 139006 =      0.000 ...   278.012 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=143009
#     Range : 0 ... 143008 =      0.000 ...   286.016 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=109481
#     Range : 0 ... 109480 =      0.000 ...   218.960 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=126456
#     Range : 0 ... 126455 =      0.000 ...   252.910 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=212710
#     Range : 0 ... 212709 =      0.000 ...   425.418 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=272987
#     Range : 0 ... 272986 =      0.000 ...   545.972 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=152033
#     Range : 0 ... 152032 =      0.000 ...   304.064 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=184159
#     Range : 0 ... 184158 =      0.000 ...   368.316 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=150308
#     Range : 0 ... 150307 =      0.000 ...   300.614 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=114681
#     Range : 0 ... 114680 =      0.000 ...   229.360 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=99628
#     Range : 0 ... 99627 =      0.000 ...   199.254 secs
# Ready.
# fiels deleted: ['YLS_NR1_EEG.mat', 'YLS_NR2_EEG.mat', 'YLS_TSR1_EEG.mat']
# concatenated: 11 files, total times ≈ 3272.0s
# Finding events on: STI
# 1242 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  92  93  94  95  96 111 112 113 114 115 116]
#
# processing YMD ...
# Creating RawArray with float64 data, n_channels=1, n_times=273639
#     Range : 0 ... 273638 =      0.000 ...   547.276 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=201285
#     Range : 0 ... 201284 =      0.000 ...   402.568 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=173658
#     Range : 0 ... 173657 =      0.000 ...   347.314 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=199659
#     Range : 0 ... 199658 =      0.000 ...   399.316 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=196135
#     Range : 0 ... 196134 =      0.000 ...   392.268 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=192283
#     Range : 0 ... 192282 =      0.000 ...   384.564 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=201783
#     Range : 0 ... 201782 =      0.000 ...   403.564 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=153431
#     Range : 0 ... 153430 =      0.000 ...   306.860 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=255762
#     Range : 0 ... 255761 =      0.000 ...   511.522 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=156133
#     Range : 0 ... 156132 =      0.000 ...   312.264 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=209135
#     Range : 0 ... 209134 =      0.000 ...   418.268 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=195810
#     Range : 0 ... 195809 =      0.000 ...   391.618 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=162583
#     Range : 0 ... 162582 =      0.000 ...   325.164 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=141981
#     Range : 0 ... 141980 =      0.000 ...   283.960 secs
# Ready.
# fiels deleted: no fiels dropped
# concatenated: 14 files, total times ≈ 5426.6s
# Finding events on: STI
# 1552 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  94  95  96 110 111 112 113
#  114 115 116]
#
# processing YMS ...
# Creating RawArray with float64 data, n_channels=1, n_times=323190
#     Range : 0 ... 323189 =      0.000 ...   646.378 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=216361
#     Range : 0 ... 216360 =      0.000 ...   432.720 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=187935
#     Range : 0 ... 187934 =      0.000 ...   375.868 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=192810
#     Range : 0 ... 192809 =      0.000 ...   385.618 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=183184
#     Range : 0 ... 183183 =      0.000 ...   366.366 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=162633
#     Range : 0 ... 162632 =      0.000 ...   325.264 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=191059
#     Range : 0 ... 191058 =      0.000 ...   382.116 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=74878
#     Range : 0 ... 74877 =      0.000 ...   149.754 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=195835
#     Range : 0 ... 195834 =      0.000 ...   391.668 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=77004
#     Range : 0 ... 77003 =      0.000 ...   154.006 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=118557
#     Range : 0 ... 118556 =      0.000 ...   237.112 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=95880
#     Range : 0 ... 95879 =      0.000 ...   191.758 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=71528
#     Range : 0 ... 71527 =      0.000 ...   143.054 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=67079
#     Range : 0 ... 67078 =      0.000 ...   134.156 secs
# Ready.
# fiels deleted: ['YMS_NR1_EEG.mat', 'YMS_NR2_EEG.mat', 'YMS_NR3_EEG.mat', 'YMS_NR4_EEG.mat', 'YMS_NR6_EEG.mat', 'YMS_NR7_EEG.mat', 'YMS_TSR1_EEG.mat', 'YMS_TSR3_EEG.mat', 'YMS_TSR5_EEG.mat']
# concatenated: 5 files, total times ≈ 1272.4s
# Finding events on: STI
# 590 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  94 111 113 115 116]
#
# processing YRH ...
# Creating RawArray with float64 data, n_channels=1, n_times=223860
#     Range : 0 ... 223859 =      0.000 ...   447.718 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=139507
#     Range : 0 ... 139506 =      0.000 ...   279.012 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=124307
#     Range : 0 ... 124306 =      0.000 ...   248.612 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=131733
#     Range : 0 ... 131732 =      0.000 ...   263.464 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=127080
#     Range : 0 ... 127079 =      0.000 ...   254.158 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=115532
#     Range : 0 ... 115531 =      0.000 ...   231.062 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=126356
#     Range : 0 ... 126355 =      0.000 ...   252.710 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=113831
#     Range : 0 ... 113830 =      0.000 ...   227.660 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=183009
#     Range : 0 ... 183008 =      0.000 ...   366.016 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=97829
#     Range : 0 ... 97828 =      0.000 ...   195.656 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=151603
#     Range : 0 ... 151602 =      0.000 ...   303.204 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=114756
#     Range : 0 ... 114755 =      0.000 ...   229.510 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=136782
#     Range : 0 ... 136781 =      0.000 ...   273.562 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=87854
#     Range : 0 ... 87853 =      0.000 ...   175.706 secs
# Ready.
# fiels deleted: ['YRH_NR1_EEG.mat', 'YRH_NR2_EEG.mat', 'YRH_TSR1_EEG.mat', 'YRH_TSR4_EEG.mat']
# concatenated: 10 files, total times ≈ 2490.5s
# Finding events on: STI
# 1110 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  92  93  94  95  96 111 112 114 115 116]
#
# processing YRK ...
# Creating RawArray with float64 data, n_channels=1, n_times=284862
#     Range : 0 ... 284861 =      0.000 ...   569.722 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=199660
#     Range : 0 ... 199659 =      0.000 ...   399.318 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=181158
#     Range : 0 ... 181157 =      0.000 ...   362.314 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=199959
#     Range : 0 ... 199958 =      0.000 ...   399.916 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=189134
#     Range : 0 ... 189133 =      0.000 ...   378.266 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=167708
#     Range : 0 ... 167707 =      0.000 ...   335.414 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=217185
#     Range : 0 ... 217184 =      0.000 ...   434.368 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=200210
#     Range : 0 ... 200209 =      0.000 ...   400.418 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=290588
#     Range : 0 ... 290587 =      0.000 ...   581.174 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=214960
#     Range : 0 ... 214959 =      0.000 ...   429.918 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=246711
#     Range : 0 ... 246710 =      0.000 ...   493.420 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=197234
#     Range : 0 ... 197233 =      0.000 ...   394.466 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=232686
#     Range : 0 ... 232685 =      0.000 ...   465.370 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=154107
#     Range : 0 ... 154106 =      0.000 ...   308.212 secs
# Ready.
# fiels deleted: no fiels dropped
# concatenated: 14 files, total times ≈ 5952.3s
# Finding events on: STI
# 1552 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  94  95  96 110 111 112 113
#  114 115 116]
#
# processing YRP ...
# Creating RawArray with float64 data, n_channels=1, n_times=250062
#     Range : 0 ... 250061 =      0.000 ...   500.122 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=221259
#     Range : 0 ... 221258 =      0.000 ...   442.516 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=172708
#     Range : 0 ... 172707 =      0.000 ...   345.414 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=189483
#     Range : 0 ... 189482 =      0.000 ...   378.964 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=175232
#     Range : 0 ... 175231 =      0.000 ...   350.462 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=158008
#     Range : 0 ... 158007 =      0.000 ...   316.014 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=169183
#     Range : 0 ... 169182 =      0.000 ...   338.364 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=192159
#     Range : 0 ... 192158 =      0.000 ...   384.316 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=312715
#     Range : 0 ... 312714 =      0.000 ...   625.428 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=234887
#     Range : 0 ... 234886 =      0.000 ...   469.772 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=292788
#     Range : 0 ... 292787 =      0.000 ...   585.574 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=231110
#     Range : 0 ... 231109 =      0.000 ...   462.218 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=247911
#     Range : 0 ... 247910 =      0.000 ...   495.820 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=155108
#     Range : 0 ... 155107 =      0.000 ...   310.214 secs
# Ready.
# fiels deleted: no fiels dropped
# concatenated: 14 files, total times ≈ 6005.2s
# Finding events on: STI
# 1552 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  94  95  96 110 111 112 113
#  114 115 116]
#
# processing YSD ...
# Creating RawArray with float64 data, n_channels=1, n_times=191936
#     Range : 0 ... 191935 =      0.000 ...   383.870 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=139133
#     Range : 0 ... 139132 =      0.000 ...   278.264 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=136857
#     Range : 0 ... 136856 =      0.000 ...   273.712 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=137807
#     Range : 0 ... 137806 =      0.000 ...   275.612 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=130381
#     Range : 0 ... 130380 =      0.000 ...   260.760 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=106105
#     Range : 0 ... 106104 =      0.000 ...   212.208 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=119106
#     Range : 0 ... 119105 =      0.000 ...   238.210 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=70027
#     Range : 0 ... 70026 =      0.000 ...   140.052 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=111107
#     Range : 0 ... 111106 =      0.000 ...   222.212 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=77403
#     Range : 0 ... 77402 =      0.000 ...   154.804 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=103129
#     Range : 0 ... 103128 =      0.000 ...   206.256 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=88879
#     Range : 0 ... 88878 =      0.000 ...   177.756 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=76453
#     Range : 0 ... 76452 =      0.000 ...   152.904 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=59854
#     Range : 0 ... 59853 =      0.000 ...   119.706 secs
# Ready.
# fiels deleted: no fiels dropped
# concatenated: 14 files, total times ≈ 3096.4s
# Finding events on: STI
# 1552 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  94  95  96 110 111 112 113
#  114 115 116]
#
# processing YSL ...
# Creating RawArray with float64 data, n_channels=1, n_times=276664
#     Range : 0 ... 276663 =      0.000 ...   553.326 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=167182
#     Range : 0 ... 167181 =      0.000 ...   334.362 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=179859
#     Range : 0 ... 179858 =      0.000 ...   359.716 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=173083
#     Range : 0 ... 173082 =      0.000 ...   346.164 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=185409
#     Range : 0 ... 185408 =      0.000 ...   370.816 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=164557
#     Range : 0 ... 164556 =      0.000 ...   329.112 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=175008
#     Range : 0 ... 175007 =      0.000 ...   350.014 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=152233
#     Range : 0 ... 152232 =      0.000 ...   304.464 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=279240
#     Range : 0 ... 279239 =      0.000 ...   558.478 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180534
#     Range : 0 ... 180533 =      0.000 ...   361.066 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=218210
#     Range : 0 ... 218209 =      0.000 ...   436.418 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=145158
#     Range : 0 ... 145157 =      0.000 ...   290.314 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=146557
#     Range : 0 ... 146556 =      0.000 ...   293.112 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=106280
#     Range : 0 ... 106279 =      0.000 ...   212.558 secs
# Ready.
# fiels deleted: no fiels dropped
# concatenated: 14 files, total times ≈ 5099.9s
# Finding events on: STI
# 1552 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  94  95  96 110 111 112 113
#  114 115 116]
#
# processing YTL ...
# Creating RawArray with float64 data, n_channels=1, n_times=221611
#     Range : 0 ... 221610 =      0.000 ...   443.220 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=189335
#     Range : 0 ... 189334 =      0.000 ...   378.668 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=209385
#     Range : 0 ... 209384 =      0.000 ...   418.768 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=204985
#     Range : 0 ... 204984 =      0.000 ...   409.968 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=208184
#     Range : 0 ... 208183 =      0.000 ...   416.366 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=162858
#     Range : 0 ... 162857 =      0.000 ...   325.714 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=186060
#     Range : 0 ... 186059 =      0.000 ...   372.118 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=62353
#     Range : 0 ... 62352 =      0.000 ...   124.704 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=116031
#     Range : 0 ... 116030 =      0.000 ...   232.060 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=99830
#     Range : 0 ... 99829 =      0.000 ...   199.658 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=119057
#     Range : 0 ... 119056 =      0.000 ...   238.112 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=119331
#     Range : 0 ... 119330 =      0.000 ...   238.660 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=72879
#     Range : 0 ... 72878 =      0.000 ...   145.756 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=58403
#     Range : 0 ... 58402 =      0.000 ...   116.804 secs
# Ready.
# fiels deleted: no fiels dropped
# concatenated: 14 files, total times ≈ 4060.6s
# Finding events on: STI
# 1385 events found on stim channel STI
# Event IDs: [ 10  11  12  13  15  20  21  90  91  92  93  94  95  96 110 111 112 113
#  114 115 116]
#
# Dropped in total 24 files：
#   - YAC_NR5_EEG.mat
#   - YAC_NR6_EEG.mat
#   - YAC_TSR4_EEG.mat
#   - YAC_TSR5_EEG.mat
#   - YDG_NR5_EEG.mat
#   - YDG_TSR5_EEG.mat
#   - YDG_TSR6_EEG.mat
#   - YFR_TSR2_EEG.mat
#   - YLS_NR1_EEG.mat
#   - YLS_NR2_EEG.mat
#   - YLS_TSR1_EEG.mat
#   - YMS_NR1_EEG.mat
#   - YMS_NR2_EEG.mat
#   - YMS_NR3_EEG.mat
#   - YMS_NR4_EEG.mat
#   - YMS_NR6_EEG.mat
#   - YMS_NR7_EEG.mat
#   - YMS_TSR1_EEG.mat
#   - YMS_TSR3_EEG.mat
#   - YMS_TSR5_EEG.mat
#   - YRH_NR1_EEG.mat
#   - YRH_NR2_EEG.mat
#   - YRH_TSR1_EEG.mat
#   - YRH_TSR4_EEG.mat

# %%
out_root = Path("/content/drive/MyDrive/Zuco2/processed_raws")
out_root.mkdir(exist_ok=True)

for sub, raw in subj_raws.items():
  out_path = out_root / f"{sub}_concat_raw.fif"
  raw.save(out_path, overwrite=True)
  print(f"Saved: {out_path}")
# Out:
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YAC_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YAC_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YAC_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YAG_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YAG_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YAG_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YAK_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YAK_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YAK_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YDG_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YDG_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YDG_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YDR_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YDR_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YDR_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YFR_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YFR_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YFR_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YFS_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YFS_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YFS_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YHS_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YHS_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YHS_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YIS_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YIS_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YIS_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YLS_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YLS_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YLS_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YMD_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YMD_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YMD_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YMS_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YMS_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YMS_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YRH_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YRH_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YRH_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YRK_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YRK_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YRK_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YRP_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YRP_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YRP_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YSD_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YSD_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YSD_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YSL_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YSL_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YSL_concat_raw.fif
# Writing /content/drive/MyDrive/Zuco2/processed_raws/YTL_concat_raw.fif
# Closing /content/drive/MyDrive/Zuco2/processed_raws/YTL_concat_raw.fif
# [done]
# Saved: /content/drive/MyDrive/Zuco2/processed_raws/YTL_concat_raw.fif
